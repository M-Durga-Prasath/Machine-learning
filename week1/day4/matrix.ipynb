# %%
import numpy as np

# %%
a = np.random.randint(0,100, size=(3,2))
b = np.random.randint(0,100, size=(2,2))
c = np.dot(a,b)
c
# Out:
# array([[4021, 2914],
#        [3190, 2332],
#        [6085, 4450]], dtype=int32)
