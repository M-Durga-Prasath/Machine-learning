# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter

# %%
roll = np.random.randint(1,7, size=1000)
# roll

# %%
count = Counter(roll)
prob = [i/1000 for i in count.values()]
prob
# Out:
# [0.166, 0.189, 0.173, 0.152, 0.158, 0.162]

# %%
plt.bar(range(1,7), prob)
# Out:
# <BarContainer object of 6 artists>
