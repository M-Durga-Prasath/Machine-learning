# %%
import torch
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")

# %%
results = model("https://ultralytics.com/images/bus.jpg")
results[0].show()
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 c:\Users\ASUS\PycharmProjects\Machine-learning\week3\day1\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 53.1ms
# Speed: 9.5ms preprocess, 53.1ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 480)

# %%
for i in results[0].boxes:
    print(i.conf)
# Out:
# tensor([0.8733], device='cuda:0')
# tensor([0.8657], device='cuda:0')
# tensor([0.8529], device='cuda:0')
# tensor([0.8253], device='cuda:0')
# tensor([0.2606], device='cuda:0')
# tensor([0.2559], device='cuda:0')
