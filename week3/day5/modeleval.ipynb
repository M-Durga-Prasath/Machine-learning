# %%
from ultralytics import YOLO

# %%
model = YOLO ("../../runs/detect/Custom_Vehicle_Detector_v1-4/weights/best.pt")
metrics = model.val(data="../day4/dataset/data.yaml")
# Out:
# Ultralytics 8.4.78  Python-3.12.4 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3050 Ti Laptop GPU, 4096MiB)
# Model summary (fused): 73 layers, 3,006,818 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 65.7115.2 MB/s, size: 92.5 KB)
# val: Scanning C:\Users\ASUS\PycharmProjects\Machine-learning\week3\day4\dataset\valid\labels.cache... 900 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 900/900  0.0s
# val: C:\Users\ASUS\PycharmProjects\Machine-learning\week3\day4\dataset\valid\images\car55.jpg: corrupt JPEG restored and saved
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 57/57 6.6it/s 8.6s0.1s
#                    all        900       1150       0.98      0.942      0.978      0.908
#                    car        182        201      0.956       0.92      0.951      0.924
#             threewheel        167        227          1      0.925      0.988      0.922
# ...

# %%
metrics.box.r
# Out:
# array([     0.9204,     0.92527,     0.97838,     0.97937,     0.90278,     0.94706])

# %%
# also train on yolov8s.pt for better results but maybe longer wait time
